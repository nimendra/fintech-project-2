# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from dotenv import load_dotenv

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# Bad key "text.kerning_factor" on line 5 in
# C:\Users\Shan\anaconda3\envs\mlenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
def load_vaccine_csv():
    df = pd.read_csv('./Resources/covidvaccine.csv')
    df = df[['user_name', 'user_location', 'user_followers', 'user_friends', 'user_favourites', 'user_verified', 'date', 'text', 'source']]
    return df

# %%
# check data types
df = load_vaccine_csv()
df.dtypes
# Out:
# C:\Users\Shan\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# user_name           object
# user_location       object
# user_followers     float64
# user_friends        object
# user_favourites     object
# user_verified       object
# date                object
# text                object
# source              object
# dtype: object

# %%
def try_parse(dateString):
    """ Try and parse a Date string in 4 different formats
    Parameter
    ----------
    dateString : string

    Returns
    ----------
    date : date
    """
    # return dateString
    # print(dateString)
    try:
        return datetime.datetime.strptime(dateString, '%Y-%m-%d %H:%M:%S')
    except Exception as e:
        try:
            return datetime.datetime.strptime(dateString, '%Y-%m-%d %H:%M')
        except Exception as e:
            try:
                return datetime.datetime.strptime(dateString, '%d-%m-%Y %H:%M')
            except Exception as e:
                return datetime.datetime.strptime(dateString, '%d-%m-%Y %H:%M:%S')

# %%
# change date column format
df = load_vaccine_csv()

df = df[df.date.notnull()]
df = df[df.date.str.contains("-")]

df['date'] = df['date'].apply(lambda t: try_parse(t))
df['xxx'] = pd.to_datetime(df['date'], format='%d-%m-%Y %H:%M')

df = df.sort_index()
df.head()
# Out:
#                  user_name              user_location  user_followers  \
# 0                 MyNewsNE                      Assam            64.0
# 1            Shubham Gupta                        NaN             1.0
# 2  Journal of Infectiology                        NaN           143.0
# 3                     Zane                        NaN            29.0
# 4       Ann-Maree O’Connor  Adelaide, South Australia            83.0
#
#   user_friends user_favourites user_verified                date  \
# 0           11             110         False 2020-08-18 12:55:00
# 1           17               0         False 2020-08-18 12:55:00
# 2          566               8         False 2020-08-18 12:46:00
# 3           25             620         False 2020-08-18 12:45:00
# 4          497           10737         False 2020-08-18 12:45:00
#
#                                                 text               source  \
# 0  Australia to Manufacture Covid-19 Vaccine and ...      Twitter Web App
# 1  #CoronavirusVaccine #CoronaVaccine #CovidVacci...  Twitter for Android
# 2  Deaths due to COVID-19 in Affected Countries\n...      Twitter Web App
# 3  @Team_Subhashree @subhashreesotwe @iamrajchoco...  Twitter for Android
# 4  @michellegrattan @ConversationEDU This is what...      Twitter Web App
#
#                   xxx
# 0 2020-08-18 12:55:00
# 1 2020-08-18 12:55:00
# 2 2020-08-18 12:46:00
# 3 2020-08-18 12:45:00
# 4 2020-08-18 12:45:00

# %%
# change data types 
df = df.astype({'user_followers': int, 'user_friends': int, 'user_favourites': int})
df.dtypes
# Out:
# user_name                  object
# user_location              object
# user_followers              int32
# user_friends                int32
# user_favourites             int32
# user_verified              object
# date               datetime64[ns]
# text                       object
# source                     object
# xxx                datetime64[ns]
# dtype: object

# %%
# drop null value 
df2 = df.dropna()

# %%
 # Download/Update the VADER Lexicon
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Shan\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
def analyse_sentimemnt_vader(df):   
    sentiments = []

    for index, row in df.iterrows():
        try:
            text = row["text"]           
            sentiment = analyzer.polarity_scores(text)
            compound = sentiment["compound"]
            pos = sentiment["pos"]
            neu = sentiment["neu"]
            neg = sentiment["neg"]
            
            sentiments.append({
                "text": text,
                "date": row['date'],
                "user_location":row['user_location'],
                "user_followers":row['user_followers'],
                "user_friends":row['user_friends'],
                "user_favourites":row['user_favourites'],
                "user_name": row['user_name'],
                "user_verified": row['user_verified'],
                "source": row['source'],
                "compound": compound,
                "positive": pos,
                "negative": neg,
                "neutral": neu
                
            })
            
        except AttributeError:
            pass
        
    # Create DataFrame
    ret_df = pd.DataFrame(sentiments)

    # Reorder DataFrame columns
    cols = ["date","user_name", "user_location","user_followers", "user_friends", "user_favourites", "text", "compound", "positive", "negative", "neutral", "user_verified", "source"]
    ret_df = ret_df[cols]
    ret_df.set_index('date', inplace=True)
    ret_df = ret_df.sort_index()

    return ret_df

# %%
# VADER sentiment scores
tweet_tone_df = analyse_sentimemnt_vader(df2)
tweet_tone_df.head()
# Out:
#                                           user_name            user_location  \
# date
# 2020-08-09 19:15:00                          Ashwin                 India 🇮🇳
# 2020-08-09 20:02:00                   K. Kartik Rao  Mumbai and Nagpur India
# 2020-08-09 21:21:00  Mac Patrick (Road Hater) Henry    German Bundesrepublik
# 2020-08-09 21:29:00                      lydia Bell                   Earth
# 2020-08-09 22:55:00                 Lou Ann Donovan              Kansas, USA
#
#                      user_followers  user_friends  user_favourites  \
# date
# 2020-08-09 19:15:00              89          3108             6780
# 2020-08-09 20:02:00             225           257            25362
# 2020-08-09 21:21:00             338           277            28305
# 2020-08-09 21:29:00            2038          1105            63422
# 2020-08-09 22:55:00            4365          4581             2505
#
#                                                                   text  \
# date
# 2020-08-09 19:15:00  Huge Thanks And Best Wishes With @SerumInstInd...
# 2020-08-09 20:02:00                   Any update of #CovidVaccine ????
# 2020-08-09 21:21:00  From a private frontline COVID nurses group to...
# 2020-08-09 21:29:00  So you want the whole world to take a #covidva...
# 2020-08-09 22:55:00  Watch to learn about the Phase 3 clinical tria...
#
#                      compound  positive  negative  neutral user_verified  \
# date
# 2020-08-09 19:15:00    0.9169     0.517       0.0    0.483         False
# 2020-08-09 20:02:00    0.0000     0.000       0.0    1.000         False
# 2020-08-09 21:21:00    0.0000     0.000       0.0    1.000         False
# 2020-08-09 21:29:00    0.0745     0.058       0.0    0.942         False
# 2020-08-09 22:55:00    0.0000     0.000       0.0    1.000         False
#
#                                   source
# date
# 2020-08-09 19:15:00  Twitter for Android
# 2020-08-09 20:02:00  Twitter for Android
# 2020-08-09 21:21:00      Twitter Web App
# 2020-08-09 21:29:00   Twitter for iPhone
# 2020-08-09 22:55:00   Twitter for iPhone

# %%
# get dummied tweets source
tweet_tone_with_dummies_df = pd.get_dummies(tweet_tone_df, columns=['source'])

# Assign 0 for False verified and 1 for True
tweet_tone_with_dummies_df['verified'] = tweet_tone_with_dummies_df['user_verified'].apply(lambda x: 1 if (x == True) else 0)

# Group each tweets into 15 minutes duration
tweet_tone_with_dummies_resampled_df = tweet_tone_with_dummies_df.resample('15min').sum()

# %%
# get pfizer 15 mins share price
pfizer_df = pd.read_csv('./Resources/Pfizer.csv', parse_dates=True, index_col='time',)
pfizer_df.index.names = ['date']
pfizer_df.head()
# Out:
#                           open       high        low      close  volume
# date
# 2020-07-31 04:15:00  35.984022  35.984022  35.984022  35.984022     215
# 2020-07-31 05:00:00  35.984022  35.984022  35.984022  35.984022     105
# 2020-07-31 05:15:00  36.002599  36.002599  36.002599  36.002599     217
# 2020-07-31 05:30:00  36.104774  36.188371  36.039754  36.039754    1850
# 2020-07-31 06:00:00  36.132640  36.132640  36.132640  36.132640     196

# %%
# calculate pfizer return
pfizer_return_df = pfizer_df[['close']].pct_change().dropna()
pfizer_return_df.rename(columns={'close': 'return'}, inplace = True)
pfizer_return_df.head()
# Out:
#                        return
# date
# 2020-07-31 05:00:00  0.000000
# 2020-07-31 05:15:00  0.000516
# 2020-07-31 05:30:00  0.001032
# 2020-07-31 06:00:00  0.002577
# 2020-07-31 06:30:00  0.005398

# %%
# define cross-correlations 
def crosscorr(datax, datay, lag=0):
    """ Lag-N cross correlation. 
    Parameters
    ----------
    lag : int, default 0
    datax, datay : pandas.Series objects of equal length

    Returns
    ----------
    crosscorr : float
    """
    return datax.corr(datay.shift(lag))

# %%
# check cross-correlations
corr_df = [crosscorr(tweet_tone_with_dummies_df['compound'],pfizer_return_df['return'], lag=i) for i in range(12)]
corr_df
# Out:
# [0.01299696057831661,
#  -0.024564681843883964,
#  0.07341057013468348,
#  -0.05624801437721832,
#  -0.02703001540268738,
#  0.008810899129803306,
#  -0.013898220139776377,
#  -0.029236019556613393,
#  0.02794315912910171,
#  0.02017365894538735,
#  -0.010294838194216026,
#  0.0268840411939124]

# %%
# Shifting tweets by 2 (30 mins) because that seems to correlate best with stock prices
pfizer_return_shift = pfizer_return_df.shift(-2)
pfizer_return_shift.dropna(inplace=True)

# %%
# combine pfizer close price and tweets 
combined_df = pd.concat([tweet_tone_with_dummies_resampled_df, pfizer_return_shift], axis=1, join='inner')
combined_df.head()
# Out:
#                      user_followers  user_friends  user_favourites  compound  \
# date
# 2020-08-10 05:30:00               0             0                0    0.0000
# 2020-08-10 07:15:00               0             0                0    0.0000
# 2020-08-10 07:30:00               0             0                0    0.0000
# 2020-08-10 07:45:00          548972           353             1343   -0.3612
# 2020-08-10 08:00:00             669          3466            11336    0.3400
#
#                      positive  negative  neutral  source_92 News HD  \
# date
# 2020-08-10 05:30:00     0.000     0.000    0.000                  0
# 2020-08-10 07:15:00     0.000     0.000    0.000                  0
# 2020-08-10 07:30:00     0.000     0.000    0.000                  0
# 2020-08-10 07:45:00     0.000     0.161    1.839                  0
# 2020-08-10 08:00:00     0.165     0.101    2.734                  0
#
#                      source_@healthpolicyw  source_A Touch of Snark  ...  \
# date                                                                 ...
# 2020-08-10 05:30:00                      0                        0  ...
# 2020-08-10 07:15:00                      0                        0  ...
# 2020-08-10 07:30:00                      0                        0  ...
# 2020-08-10 07:45:00                      0                        0  ...
# 2020-08-10 08:00:00                      0                        0  ...
#
#                      source_happs.tv  source_iHeartMedia Publishing  \
# date
# 2020-08-10 05:30:00                0                              0
# 2020-08-10 07:15:00                0                              0
# 2020-08-10 07:30:00                0                              0
# 2020-08-10 07:45:00                0                              0
# 2020-08-10 08:00:00                0                              0
#
#                      source_iLoveKent2  source_iNVEZZ  source_iOS  \
# date
# 2020-08-10 05:30:00                  0              0           0
# 2020-08-10 07:15:00                  0              0           0
# 2020-08-10 07:30:00                  0              0           0
# 2020-08-10 07:45:00                  0              0           0
# 2020-08-10 08:00:00                  0              0           0
#
#                      source_recurpost.com  source_robly_marketing  \
# date
# 2020-08-10 05:30:00                     0                       0
# 2020-08-10 07:15:00                     0                       0
# 2020-08-10 07:30:00                     0                       0
# 2020-08-10 07:45:00                     0                       0
# 2020-08-10 08:00:00                     0                       0
#
#                      source_syllogiTweeter  verified    return
# date
# 2020-08-10 05:30:00                      0         0 -0.002848
# 2020-08-10 07:15:00                      0         0  0.000260
# 2020-08-10 07:30:00                      0         0 -0.000519
# 2020-08-10 07:45:00                      0         1  0.000000
# 2020-08-10 08:00:00                      0         0  0.000519
#
# [5 rows x 219 columns]

# %%
# Find null values
for column in combined_df.columns:
    print(f"Column {column} has {combined_df[column].isnull().sum()} null values")
# Out:
# Column user_followers has 0 null values
# Column user_friends has 0 null values
# Column user_favourites has 0 null values
# Column compound has 0 null values
# Column positive has 0 null values
# Column negative has 0 null values
# Column neutral has 0 null values
# Column source_92 News HD has 0 null values
# Column source_@healthpolicyw has 0 null values
# Column source_A Touch of Snark has 0 null values
# Column source_Africa Newsroom has 0 null values
# Column source_AgoraPulse Manager has 0 null values
# Column source_Algotiger has 0 null values
# Column source_Amplifr has 0 null values
# Column source_BLOX CMS has 0 null values
# Column source_Bambu by Sprout Social has 0 null values
# Column source_Bitly has 0 null values
# Column source_Blog2Social APP has 0 null values
# Column source_Bradfordian Bot has 0 null values
# Column source_Buffer has 0 null values
# Column source_CV SNAP  has 0 null values
# Column source_Canva has 0 null values
# Column source_ChimpReports_ has 0 null values
# Column source_Chromographics has 0 null values
# Column source_CinchShare has 0 null values
# Column source_Cloud Campaign has 0 null values
# Column source_CoSchedule has 0 null values
# Column source_Constant Contact - Social Posts has 0 null values
# Column source_ContentCal Studio has 0 null values
# Column source_ContentStudio.io has 0 null values
# Column source_CrowdControlHQ has 0 null values
# Column source_Crowdfire App has 0 null values
# Column source_CruzNews has 0 null values
# Column source_Daily Voice Sync has 0 null values
# Column source_Devdiscourse News Desk has 0 null values
# Column source_Dynamic Signal has 0 null values
# Column source_ETRetail.com has 0 null values
# Column source_EastMojo has 0 null values
# Column source_Echobox has 0 null values
# Column source_Echofon has 0 null values
# Column source_FMG Social has 0 null values
# Column source_FS Poster has 0 null values
# Column source_Facelift-Cloud has 0 null values
# Column source_Falcon Social Media Management  has 0 null values
# Column source_Fan Page Robot has 0 null values
# Column source_Fanbooster by Traject has 0 null values
# Column source_Fenix 2 has 0 null values
# Column source_Fenix for iOS has 0 null values
# Column source_Flamingo for Android has 0 null values
# Column source_Foursquare has 0 null values
# Column source_GV6 Regulated has 0 null values
# Column source_Gain Platform has 0 null values
# Column source_Gfycat Twitter has 0 null values
# Column source_Google has 0 null values
# Column source_GroupTweet has 0 null values
# Column source_HW news english has 0 null values
# Column source_Hacker Noon has 0 null values
# Column source_HeyOrca has 0 null values
# Column source_Higher Logic MA Twitter App has 0 null values
# Column source_Hocalwire Social Share has 0 null values
# Column source_Hootsuite Inc. has 0 null values
# Column source_HubSpot has 0 null values
# Column source_IFTTT has 0 null values
# Column source_Instagram has 0 null values
# Column source_Integromat has 0 null values
# Column source_Jagwire Tweets has 0 null values
# Column source_Jan Bot Films has 0 null values
# Column source_Khoros has 0 null values
# Column source_Khoros Marketing has 0 null values
# Column source_LatelyAI has 0 null values
# Column source_LaterMedia has 0 null values
# Column source_Lightful has 0 null values
# Column source_LinkedIn has 0 null values
# Column source_Loomly has 0 null values
# Column source_Mailchimp has 0 null values
# Column source_Market Beam has 0 null values
# Column source_MavSocial App has 0 null values
# Column source_MeetEdgar has 0 null values
# Column source_Meltwater Social has 0 null values
# Column source_Metricool has 0 null values
# Column source_MickeyBlog.com Updates has 0 null values
# Column source_Missinglettr has 0 null values
# Column source_NDTV News Studio has 0 null values
# Column source_NDTV Profit Latest Update has 0 null values
# Column source_Naija.fm has 0 null values
# Column source_National Herald has 0 null values
# Column source_Newsfile News Tweets has 0 null values
# Column source_Nintendo Switch Share has 0 null values
# Column source_Nonli has 0 null values
# Column source_Note BlockChain has 0 null values
# Column source_OTDC has 0 null values
# Column source_Oktopost has 0 null values
# Column source_OneUp App has 0 null values
# Column source_OnlyWire App has 0 null values
# Column source_Orlo has 0 null values
# Column source_Oyeyeah has 0 null values
# Column source_PB Update has 0 null values
# Column source_PLANOLY has 0 null values
# Column source_PNSposter has 0 null values
# Column source_Paper.li has 0 null values
# Column source_Pardot has 0 null values
# Column source_Percolate has 0 null values
# Column source_Periscope has 0 null values
# Column source_Planable has 0 null values
# Column source_Plume for Android has 0 null values
# Column source_Politwoops has 0 null values
# Column source_Post Planner Inc. has 0 null values
# Column source_PostBeyond has 0 null values
# Column source_Postcron App has 0 null values
# Column source_Postfity.com has 0 null values
# Column source_Postoplan  has 0 null values
# Column source_PromoRepublic has 0 null values
# Column source_Publer  has 0 null values
# Column source_Qnary.io has 0 null values
# Column source_RSS Masher - Dev has 0 null values
# Column source_Rallio has 0 null values
# Column source_Raven Tools has 0 null values
# Column source_Repurpose.io has 0 null values
# Column source_Reputation.com-Social has 0 null values
# Column source_Revive Social App has 0 null values
# Column source_Rss2Twitter for La Forge has 0 null values
# Column source_SEMrush Social Media Tool has 0 null values
# Column source_SOCi - Simplifying Social Media has 0 null values
# Column source_Safari on iOS has 0 null values
# Column source_Salesforce - Social Studio has 0 null values
# Column source_Samrudhi Global has 0 null values
# Column source_Sendible has 0 null values
# Column source_Sharpspring has 0 null values
# Column source_Shawagunk Journal has 0 null values
# Column source_Sked Social has 0 null values
# Column source_Smarp. has 0 null values
# Column source_SmartNews | スマートニュース has 0 null values
# Column source_SmarterQueue has 0 null values
# Column source_SnapStream TV Search has 0 null values
# Column source_SoCast Digital has 0 null values
# Column source_Social Practice has 0 null values
# Column source_Social Reputation has 0 null values
# Column source_SocialBee.io v2 has 0 null values
# Column source_SocialFlow has 0 null values
# Column source_SocialNewsDesk has 0 null values
# Column source_SocialOomph has 0 null values
# Column source_SocialPilot.co has 0 null values
# Column source_SocialPost App has 0 null values
# Column source_Socialbakers has 0 null values
# Column source_Spreaker has 0 null values
# Column source_Sprinklr has 0 null values
# Column source_Sprinklr Publisher has 0 null values
# Column source_Sprinklr Publishing has 0 null values
# Column source_Sprout Social has 0 null values
# Column source_Squarespace has 0 null values
# Column source_Sqwarkr has 0 null values
# Column source_Statusbrew has 0 null values
# Column source_Stencil App has 0 null values
# Column source_StockTwits Web has 0 null values
# Column source_Swat.io has 0 null values
# Column source_TTN SPO traffic has 0 null values
# Column source_Talon Android has 0 null values
# Column source_The Healthsite has 0 null values
# Column source_The Social Jukebox has 0 null values
# Column source_The Tweeted Times has 0 null values
# Column source_The Unshackled has 0 null values
# Column source_ThreadReaderApp has 0 null values
# Column source_Threader_client has 0 null values
# Column source_Thryv has 0 null values
# Column source_True Anthem has 0 null values
# Column source_Tumblr has 0 null values
# Column source_Tweepsmap has 0 null values
# Column source_TweetCaster for Android has 0 null values
# Column source_TweetCaster for iOS has 0 null values
# Column source_TweetDeck has 0 null values
# Column source_Tweetbot for Mac has 0 null values
# Column source_Tweetbot for iΟS has 0 null values
# Column source_Tweetlogix has 0 null values
# Column source_Twidere for Android has 0 null values
# Column source_TwitPane for Android has 0 null values
# Column source_Twitter Ads has 0 null values
# Column source_Twitter Media Studio has 0 null values
# Column source_Twitter Media Studio - LiveCut has 0 null values
# Column source_Twitter VIT App for iOS has 0 null values
# Column source_Twitter Web App has 0 null values
# Column source_Twitter Web Client has 0 null values
# Column source_Twitter for Advertisers has 0 null values
# Column source_Twitter for Advertisers (legacy) has 0 null values
# Column source_Twitter for Android has 0 null values
# Column source_Twitter for Mac has 0 null values
# Column source_Twitter for iPad has 0 null values
# Column source_Twitter for iPhone has 0 null values
# Column source_Twitterrific for iOS has 0 null values
# Column source_Twittimer has 0 null values
# Column source_UberSocial for Android has 0 null values
# Column source_United blog to twitter has 0 null values
# Column source_Unshackled Content Poster has 0 null values
# Column source_Untappd has 0 null values
# Column source_Updates Poster has 0 null values
# Column source_Upflow has 0 null values
# Column source_Video App Dream Big has 0 null values
# Column source_Vimeo has 0 null values
# Column source_Weebly App has 0 null values
# Column source_Wildmoka has 0 null values
# Column source_Will Lockwood has 0 null values
# Column source_WordPress.com has 0 null values
# Column source_Zapier.com has 0 null values
# Column source_Zoho Social has 0 null values
# Column source_allAfrica.com has 0 null values
# Column source_bitcoinagile has 0 null values
# Column source_dlvr.it has 0 null values
# Column source_drumup.io has 0 null values
# Column source_eClincher has 0 null values
# Column source_econ b2b post has 0 null values
# Column source_happs.tv has 0 null values
# Column source_iHeartMedia Publishing has 0 null values
# Column source_iLoveKent2 has 0 null values
# Column source_iNVEZZ has 0 null values
# Column source_iOS has 0 null values
# Column source_recurpost.com has 0 null values
# Column source_robly_marketing has 0 null values
# Column source_syllogiTweeter has 0 null values
# Column verified has 0 null values
# Column return has 0 null values

# %%
# classify return column into Boolean value
def changeReturn(returns):
    if returns > 0:
        return 1
    elif returns < 0:
        return -1
    else:
        return 0
combined_df['return'] = combined_df['return'].apply(changeReturn)
combined_df.head()
# Out:
#                      user_followers  user_friends  user_favourites  compound  \
# date
# 2020-08-10 05:30:00               0             0                0    0.0000
# 2020-08-10 07:15:00               0             0                0    0.0000
# 2020-08-10 07:30:00               0             0                0    0.0000
# 2020-08-10 07:45:00          548972           353             1343   -0.3612
# 2020-08-10 08:00:00             669          3466            11336    0.3400
#
#                      positive  negative  neutral  source_92 News HD  \
# date
# 2020-08-10 05:30:00     0.000     0.000    0.000                  0
# 2020-08-10 07:15:00     0.000     0.000    0.000                  0
# 2020-08-10 07:30:00     0.000     0.000    0.000                  0
# 2020-08-10 07:45:00     0.000     0.161    1.839                  0
# 2020-08-10 08:00:00     0.165     0.101    2.734                  0
#
#                      source_@healthpolicyw  source_A Touch of Snark  ...  \
# date                                                                 ...
# 2020-08-10 05:30:00                      0                        0  ...
# 2020-08-10 07:15:00                      0                        0  ...
# 2020-08-10 07:30:00                      0                        0  ...
# 2020-08-10 07:45:00                      0                        0  ...
# 2020-08-10 08:00:00                      0                        0  ...
#
#                      source_happs.tv  source_iHeartMedia Publishing  \
# date
# 2020-08-10 05:30:00                0                              0
# 2020-08-10 07:15:00                0                              0
# 2020-08-10 07:30:00                0                              0
# 2020-08-10 07:45:00                0                              0
# 2020-08-10 08:00:00                0                              0
#
#                      source_iLoveKent2  source_iNVEZZ  source_iOS  \
# date
# 2020-08-10 05:30:00                  0              0           0
# 2020-08-10 07:15:00                  0              0           0
# 2020-08-10 07:30:00                  0              0           0
# 2020-08-10 07:45:00                  0              0           0
# 2020-08-10 08:00:00                  0              0           0
#
#                      source_recurpost.com  source_robly_marketing  \
# date
# 2020-08-10 05:30:00                     0                       0
# 2020-08-10 07:15:00                     0                       0
# 2020-08-10 07:30:00                     0                       0
# 2020-08-10 07:45:00                     0                       0
# 2020-08-10 08:00:00                     0                       0
#
#                      source_syllogiTweeter  verified  return
# date
# 2020-08-10 05:30:00                      0         0      -1
# 2020-08-10 07:15:00                      0         0       1
# 2020-08-10 07:30:00                      0         0      -1
# 2020-08-10 07:45:00                      0         1       0
# 2020-08-10 08:00:00                      0         0       1
#
# [5 rows x 219 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Define features set
X = combined_df.copy()
X.drop("return", axis=1, inplace=True)
X.head()
# Out:
#                      user_followers  user_friends  user_favourites  compound  \
# date
# 2020-08-10 05:30:00               0             0                0    0.0000
# 2020-08-10 07:15:00               0             0                0    0.0000
# 2020-08-10 07:30:00               0             0                0    0.0000
# 2020-08-10 07:45:00          548972           353             1343   -0.3612
# 2020-08-10 08:00:00             669          3466            11336    0.3400
#
#                      positive  negative  neutral  source_92 News HD  \
# date
# 2020-08-10 05:30:00     0.000     0.000    0.000                  0
# 2020-08-10 07:15:00     0.000     0.000    0.000                  0
# 2020-08-10 07:30:00     0.000     0.000    0.000                  0
# 2020-08-10 07:45:00     0.000     0.161    1.839                  0
# 2020-08-10 08:00:00     0.165     0.101    2.734                  0
#
#                      source_@healthpolicyw  source_A Touch of Snark  ...  \
# date                                                                 ...
# 2020-08-10 05:30:00                      0                        0  ...
# 2020-08-10 07:15:00                      0                        0  ...
# 2020-08-10 07:30:00                      0                        0  ...
# 2020-08-10 07:45:00                      0                        0  ...
# 2020-08-10 08:00:00                      0                        0  ...
#
#                      source_econ b2b post  source_happs.tv  \
# date
# 2020-08-10 05:30:00                     0                0
# 2020-08-10 07:15:00                     0                0
# 2020-08-10 07:30:00                     0                0
# 2020-08-10 07:45:00                     0                0
# 2020-08-10 08:00:00                     0                0
#
#                      source_iHeartMedia Publishing  source_iLoveKent2  \
# date
# 2020-08-10 05:30:00                              0                  0
# 2020-08-10 07:15:00                              0                  0
# 2020-08-10 07:30:00                              0                  0
# 2020-08-10 07:45:00                              0                  0
# 2020-08-10 08:00:00                              0                  0
#
#                      source_iNVEZZ  source_iOS  source_recurpost.com  \
# date
# 2020-08-10 05:30:00              0           0                     0
# 2020-08-10 07:15:00              0           0                     0
# 2020-08-10 07:30:00              0           0                     0
# 2020-08-10 07:45:00              0           0                     0
# 2020-08-10 08:00:00              0           0                     0
#
#                      source_robly_marketing  source_syllogiTweeter  verified
# date
# 2020-08-10 05:30:00                       0                      0         0
# 2020-08-10 07:15:00                       0                      0         0
# 2020-08-10 07:30:00                       0                      0         0
# 2020-08-10 07:45:00                       0                      0         1
# 2020-08-10 08:00:00                       0                      0         0
#
# [5 rows x 218 columns]

# %%
# Define target vector
y = combined_df["return"].values.reshape(-1, 1)
y[:5]
# Out:
# array([[-1],
#        [ 1],
#        [-1],
#        [ 0],
#        [ 1]], dtype=int64)

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
X_scaler = scaler.fit(X_train)

# %%
# Scale the training data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the random forest classifier instance
rf_model = RandomForestClassifier(n_estimators=500, random_state=78)

# %%
# Fit the model
rf_model = rf_model.fit(X_train_scaled, y_train)
# Out:
# C:\Users\Shan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
# Making predictions using the testing data
predictions = rf_model.predict(X_test_scaled)

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual -1", "Actual 0", "Actual 1"], columns=["Predicted -1", "Predicted 0", "Predicted 1"]
)
# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#            Predicted -1  Predicted 0  Predicted 1
# Actual -1           281            2          604
# Actual 0             66            1          122
# Actual 1            290            2          615
# Accuracy Score : 0.4523449319213313
# Classification Report
#               precision    recall  f1-score   support
#
#           -1       0.44      0.32      0.37       887
#            0       0.20      0.01      0.01       189
#            1       0.46      0.68      0.55       907
#
#     accuracy                           0.45      1983
#    macro avg       0.37      0.33      0.31      1983
# weighted avg       0.43      0.45      0.42      1983

# %%
# Get the feature importance array
importances = rf_model.feature_importances_

# %%
# List the top 10 most important features
importances_sorted = sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
importances_sorted[:10]
# Out:
# [(0.10926365438707535, 'user_followers'),
#  (0.10911536896069303, 'user_friends'),
#  (0.10910408941725393, 'user_favourites'),
#  (0.0886969185759397, 'neutral'),
#  (0.08655337448682683, 'compound'),
#  (0.08270179404605137, 'positive'),
#  (0.07024882935532288, 'negative'),
#  (0.04865504911005096, 'source_Twitter Web App'),
#  (0.043009434305405214, 'source_Twitter for iPhone'),
#  (0.042753432029189055, 'source_Twitter for Android')]
