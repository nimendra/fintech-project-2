# %%
# !pip install yfinance
import alpaca_trade_api as tradeapi
import os    
from dotenv  import load_dotenv
from pathlib import Path
import pandas as pd
import yfinance as yf

# %% [markdown]
# ## Yahoo Finance

# %%
yf_stocks_df = yf.download(tickers = "DOW AAPL TRV BA JNJ PFE BTC-USD", interval='15m', start="2020-12-30", end="2021-02-15")
yf_stocks_df.head()
# Out:
# [*********************100%***********************]  7 of 7 completed
#                           Adj Close                                   Close  \
#                                AAPL  BA       BTC-USD DOW JNJ PFE TRV  AAPL
# Datetime
# 2020-12-29 13:00:00+00:00       NaN NaN  26907.812500 NaN NaN NaN NaN   NaN
# 2020-12-29 13:15:00+00:00       NaN NaN  26886.263672 NaN NaN NaN NaN   NaN
# 2020-12-29 13:30:00+00:00       NaN NaN  26864.822266 NaN NaN NaN NaN   NaN
# 2020-12-29 13:45:00+00:00       NaN NaN  26875.275391 NaN NaN NaN NaN   NaN
# 2020-12-29 14:00:00+00:00       NaN NaN  26697.210938 NaN NaN NaN NaN   NaN
#
#                                              ... Open         Volume      \
#                            BA       BTC-USD  ...  JNJ PFE TRV   AAPL  BA
# Datetime                                     ...
# 2020-12-29 13:00:00+00:00 NaN  26907.812500  ...  NaN NaN NaN    NaN NaN
# 2020-12-29 13:15:00+00:00 NaN  26886.263672  ...  NaN NaN NaN    NaN NaN
# ...

# %% [markdown]
# ## Alpaca API

# %%
# Load .env environment variables
load_dotenv()
# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")
# Create the Alpaca API object
alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")

# %%
# Format current date as ISO format
start = pd.Timestamp("2020-08-15", tz="America/New_York").isoformat()
end = pd.Timestamp("2021-02-15", tz="America/New_York").isoformat()
# Set timeframe to one day ('1D') for the Alpaca API
timeframe = "15Min"
# Set the tickers
tickers = ['DOW', 'AAPL', 'TRV', 'BA', 'JNJ', 'PFE']

# %%
df_portfolio = alpaca.get_barset(
    tickers,
    timeframe,
    start = start,
    end = end
).df
df_portfolio.head()
# Out:
#                           AAPL                             BA                  \
#                           open high low close volume     open    high     low
# time
# 2021-02-09 10:30:00-05:00  NaN  NaN NaN   NaN    NaN      NaN     NaN     NaN
# 2021-02-09 10:45:00-05:00  NaN  NaN NaN   NaN    NaN      NaN     NaN     NaN
# 2021-02-09 11:00:00-05:00  NaN  NaN NaN   NaN    NaN  211.980  212.33  211.69
# 2021-02-09 11:15:00-05:00  NaN  NaN NaN   NaN    NaN  211.930  212.49  211.70
# 2021-02-09 11:30:00-05:00  NaN  NaN NaN   NaN    NaN  212.555  215.84  212.50
#
#                                             ...  PFE                        \
#                             close   volume  ... open high low close volume
# time                                        ...
# 2021-02-09 10:30:00-05:00     NaN      NaN  ...  NaN  NaN NaN   NaN    NaN
# 2021-02-09 10:45:00-05:00     NaN      NaN  ...  NaN  NaN NaN   NaN    NaN
# ...

# %% [markdown]
# ## Alpha Api

# %%
from alpha_vantage.timeseries import TimeSeries

# %%
load_dotenv()
alpha_api=os.getenv('ALPHA')
ts = TimeSeries(key=alpha_api,output_format='csv')

# %%
def get_price(symbol, interval):
    df = []
    data, meta= ts.get_intraday_extended(symbol=symbol, interval='15min', slice=interval)
    for row in data:
        df.append(row)
    df = pd.DataFrame(df, columns=df[0])
    df.drop(index=0,inplace=True)
    
    return df

# %%
df1 = get_price('PFE','year1month7')

# %%
df2 = get_price('PFE','year1month6')

# %%
df3 = get_price('PFE','year1month5')

# %%
df4 = get_price('PFE','year1month4')

# %%
df5 = get_price('PFE','year1month3')

# %%
df6 = get_price('PFE','year1month2')

# %%
df7 = get_price('PFE','year1month1')

# %%
df_pfe = pd.concat([df1,df2,df3,df4,df5,df6,df7],  axis=0).set_index('time').sort_index()
df_pfe.tail()
# Out:
# C:\Users\Shan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                              close           high            low  \
# time
# 2020-12-24 17:00:00  36.8294565517  36.8987034483  36.8294565517
# NaN                            NaN            NaN            NaN
# NaN                            NaN            NaN            NaN
# NaN                            NaN            NaN            NaN
# NaN                            NaN            NaN            NaN
#
#                               open volume  \
# time
# 2020-12-24 17:00:00  36.8987034483   6811
# NaN                            NaN    NaN
# ...

# %%
df_pfe.to_csv('Pfizer.csv')

# %%
ts = TimeSeries(key='CEHZKY8UT3FCCUSH',output_format='csv')

# %%
df1_JNJ = get_price('JNJ','year1month7')
df2_JNJ = get_price('JNJ','year1month6')
df3_JNJ = get_price('JNJ','year1month6')
df4_JNJ = get_price('JNJ','year1month6')
df5_JNJ = get_price('JNJ','year1month6')
df6_JNJ = get_price('JNJ','year1month6')
df7_JNJ = get_price('JNJ','year1month6')
df_jnj= pd.concat([df1_JNJ,df2_JNJ,df3_JNJ,df4_JNJ,df5_JNJ,df6_JNJ,df7_JNJ],  axis=0).set_index('time').sort_index()
# Out:
# C:\Users\Shan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
df_jnj.to_csv('Jhonson.csv')
